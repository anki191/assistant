# %% [markdown]
# ### My Assistant:)

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os
import smtplib
import subprocess



engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
#print(voices[0].id)
engine.setProperty('voices',voices[0].id)

def speak(audio):
  engine.say(audio)
  engine.runAndWait()


def WishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
        speak("Good Morning! Sir")

    elif hour>=12 and hour<18:
        speak("Good Afternoon! Sir")
    
    else:
        speak("Good Evening! Sir")

    speak("I am jarvis. Please tell me, How may I help you ")
    
def takeCommand():
    #It takes microphone input from the user and returns the string output.

    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listerning...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio,language='en-in')
        print(f"User said: {query}\n")

    except Exception as e:
        print(e)

        print("Say that again please...")
        return "None"
    return query

if __name__=="__main__":
     WishMe()
     while True:
        #if 1:
        query = takeCommand().lower()

     # Logic for executing tasks nased on query
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia","")
            results = wikipedia.summary(query, sentences=2)
            speak("According to Wikipedia")
            print(results)
            speak(results)

        elif 'open youtube' in query:
            speak('Opening Youtube, sir...')
            webbrowser.open("youtube.com")

        elif 'open google' in query:
            speak('Opening googel, sir...')
            webbrowser.open("google.com")

        elif 'play music' in query:
            speak('Playing the music, sir...')
            music_dir = 'C:\\Users\\HP\\Music'
            songs = os.listdir(music_dir)
            print(songs)
            os.startfile(os.path.join(music_dir, songs[0]))

        elif 'the time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"Sir, the time is {strTime}")

        elif 'thank you jarvis' in query:
            speak('Welcome, sir...')

        elif 'how are you' in query:
            speak("I am fine, Thank you")
            speak("How are you, Sir")
 
        elif 'fine' in query or "good" in query:
            speak("It's good to know that your fine")

        elif "who are you" in query:
            speak("I am your virtual assistant sir")

        elif 'exit' in query:
            speak("Thanks for giving me your time")
            exit()
# Out:
# Listerning...
# Recognizing...
# User said: open YouTube
#
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
# User said: Solapur Aane Wale internet mein
#
# Listerning...
# Recognizing...
# User said: Rukmani Devi
#
# Listerning...
# Recognizing...
# User said: elcb ke Hindi
#
# Listerning...
# Recognizing...
# User said: is type ka
#
# Listerning...
# Recognizing...
# User said: Rukmani Devi Google open Google
#
# Listerning...
# Recognizing...
# User said: set karna padega
#
# Listerning...
# Recognizing...
# User said: Teri Ja Jo Main Jo web browser hai na vah TV electro raha hai
#
# Listerning...
# Recognizing...
# User said: Tomar
#
# Listerning...
# Recognizing...
# User said: guitar kaise dalte hai abhi isko yahan se
#
# Listerning...
# Recognizing...
# User said: Jalgaon Shayari download is download
#
# Listerning...
# Recognizing...
# User said: naam bhi karna hai
#
# Listerning...
# Recognizing...
# User said: School
#
# Listerning...
# Recognizing...
# User said: delete kar do
#
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
# User said: vah De De aapke Teri hading
#
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
# User said: speech model
#
# Listerning...
# Recognizing...
# User said: speech model my sister
#
# Listerning...
# Recognizing...
#
# Say that again please...
# Listerning...
# Recognizing...
# User said: who is Kabhi upar se naam change karne ka
#
# Listerning...
# Recognizing...
# User said: my assistant
#
# Listerning...
# Recognizing...
# User said: v9
#
# Listerning...
# Recognizing...
